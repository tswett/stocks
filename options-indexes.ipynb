# %%
import os.path
import pandas

# %%
all_data = None

for day in range(1, 31):
    filename = f'options-data/bb_options_201903{day:02d}.csv'
    
    if os.path.isfile(filename):
        day_data = pandas.read_csv(filename)
        day_data['QuoteDate'] = f'03/{day:02d}/2019'

        if all_data is None:
            all_data = day_data
        else:
            all_data = all_data.append(day_data)

all_data
# Out:
#     UnderlyingSymbol  UnderlyingPrice Exchange        OptionRoot  OptionExt  \
# 0                  T            30.82        *  T190301C00022000        NaN
# 1                  T            30.82        *  T190301P00022000        NaN
# 2                  T            30.82        *  T190301C00023000        NaN
# 3                  T            30.82        *  T190301P00023000        NaN
# 4                  T            30.82        *  T190301C00023500        NaN
# ..               ...              ...      ...               ...        ...
# 805                T            31.36        *  T210115P00045000        NaN
# 806                T            31.36        *  T210115C00047000        NaN
# 807                T            31.36        *  T210115P00047000        NaN
# 808                T            31.36        *  T210115C00050000        NaN
# 809                T            31.36        *  T210115P00050000        NaN
#
# ...
