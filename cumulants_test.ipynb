# %%
import distributions

# %%
test_dist = distributions.NigDistribution(0.4, -0.07, 0.5, 2.0)
print(test_dist.mean)
print(test_dist.variance)
print(test_dist.kappa_3)
print(test_dist.kappa_4)
# Out:
# 0.1445142987166821
# 5.238805582143397
# -7.093160362669977
# 117.3373492802365

# %%
test_dist_2 = distributions.NigDistribution(0.4, -0.07, 0.00005, 0.0002)
print(test_dist_2.mean)
print(test_dist_2.variance)
print(test_dist_2.kappa_3)
print(test_dist_2.kappa_4)
# Out:
# 1.445142987166821e-05
# 0.0005238805582143397
# -0.0007093160362669975
# 0.011733734928023645

# %%
test_dist.plot_cdf(-20, 10)

# %%
test_dist_2.plot_cdf(-0.004, 0.002)
